# %% [markdown]
# ## I ``DataFrames``
# Il **DataFrame** è una struttura dati bidimensionale composta da colonne e righe.

# %%
import pandas as pd

# %% [markdown]
# la variabile `df` assumera' come valore il dataframe

# %%
df = pd.read_csv('./data/pokemon_list.csv')

df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# `df.head()` restituisce di default i primi 5 valori del dataframe

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# Il numero di righe da far visualizzare puo' essere passato alla funzione come parametro

# %%
df.head(2)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
#
#    Generation  Legendary
# 0           1      False
# 1           1      False

# %% [markdown]
# `df.tail()` ha lo stesso funzionamento di `df.head()`, tuttavia restituisce i valori partendo dal fondo

# %%
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
df.tail(2)
# Out:
#        #                Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 798  720  HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721           Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 798      130     80           6       True
# 799       90     70           6       True

# %% [markdown]
# `df.columns` permette di vedere i nomi delle colonne

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# `df.index` ripoprta i valori degli *index* del *DataFrame*

# %%
df.index
# Out:
# RangeIndex(start=0, stop=800, step=1)

# %% [markdown]
# `df['column_name']` permette di visualizzare solo i valori della colonna selezionata

# %%
df['Name']
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %% [markdown]
# E' possibile visualizzare piu' colonne passandogli una lista come parametro

# %%
df[['Name', 'Type 1', 'Type 2']]
# Out:
#                       Name   Type 1  Type 2
# 0                Bulbasaur    Grass  Poison
# 1                  Ivysaur    Grass  Poison
# 2                 Venusaur    Grass  Poison
# 3    VenusaurMega Venusaur    Grass  Poison
# 4               Charmander     Fire     NaN
# ..                     ...      ...     ...
# 795                Diancie     Rock   Fairy
# 796    DiancieMega Diancie     Rock   Fairy
# 797    HoopaHoopa Confined  Psychic   Ghost
# 798     HoopaHoopa Unbound  Psychic    Dark
# 799              Volcanion     Fire   Water
#
# [800 rows x 3 columns]

# %% [markdown]
# E' anche possibile combinare alcune delle cose sopracitate

# %%
df[['Name', 'Type 1', 'Type 2']].head(10)
# Out:
#                         Name Type 1  Type 2
# 0                  Bulbasaur  Grass  Poison
# 1                    Ivysaur  Grass  Poison
# 2                   Venusaur  Grass  Poison
# 3      VenusaurMega Venusaur  Grass  Poison
# 4                 Charmander   Fire     NaN
# 5                 Charmeleon   Fire     NaN
# 6                  Charizard   Fire  Flying
# 7  CharizardMega Charizard X   Fire  Dragon
# 8  CharizardMega Charizard Y   Fire  Flying
# 9                   Squirtle  Water     NaN

# %% [markdown]
# Oltre a riportare colonne specifiche è possibile eseguire operazioni

# %%
df[df['Type 1'] == 'Fire']
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %% [markdown]
# All'interno possono essere inserite piu' condizioni raggruppandole tra parentesi tonde.<br>
# [Docs](https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#boolean-indexing)

# %%
df[(df['Type 1'] == 'Fire') & (df['Type 2'] == 'Flying')]
# Out:
#        #                       Name Type 1  Type 2   HP  Attack  Defense  \
# 6      6                  Charizard   Fire  Flying   78      84       78
# 8      6  CharizardMega Charizard Y   Fire  Flying   78     104       78
# 158  146                    Moltres   Fire  Flying   90     100       90
# 270  250                      Ho-oh   Fire  Flying  106     130       90
# 730  662                Fletchinder   Fire  Flying   62      73       55
# 731  663                 Talonflame   Fire  Flying   78      81       71
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 6        109       85    100           1      False
# 8        159      115    100           1      False
# 158      125       85     90           1       True
# 270      110      154     90           2       True
# 730       56       52     84           6      False
# 731       74       69    126           6      False

# %% [markdown]
# `df.iloc[index]` serve per selezionare una singola riga, specificandone il suo indice

# %%
df.iloc[1]
# Out:
# #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object

# %% [markdown]
# Puo' anche essere utilizzato per selezionare piu' righe assieme

# %%
df.iloc[[1,3,5]]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 5  5             Charmeleon   Fire     NaN  58      64       58       80
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 3      120     80           1      False
# 5       65     80           1      False

# %%
df.iloc[1:5] # L'ultimo numero e' escluso
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# Puo' essere anche utilizzato per selezionare solo alcune colonne

# %%
df.iloc[1:3, [1,2,4]]
# Out:
#        Name Type 1  HP
# 1   Ivysaur  Grass  60
# 2  Venusaur  Grass  80

# %% [markdown]
# Molto similmente, `df.loc[condition]` serve a ottenere un inseme di righe e/o colonne che rispettano una certa condizione, oltre ad utilizzare gli indici è possibile anche utilizzare gli indici delle righe e i nomi delle colonne

# %%
df.loc[15:21, ['Type 1', 'Speed']]
# Out:
#     Type 1  Speed
# 15     Bug     70
# 16     Bug     50
# 17     Bug     35
# 18     Bug     75
# 19     Bug    145
# 20  Normal     56
# 21  Normal     71

# %% [markdown]
# `df.sort_values('column_name')` riordina il dataframe in base alla colonna selezionata

# %%
df.sort_values('Name')
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# Puo' essere anche selezionato di invertire l'
# ordine

# %%
df.sort_values('Name', ascending=False)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# In piu' e' possibile specificare piu' di una colonna in modo che se due campi risultassero uguali il programma li riordinerebbe in base al resto delle colonne selezionate andando in ordine

# %%
df.sort_values(['Generation', 'Name'])
# Out:
#        #                       Name   Type 1  Type 2   HP  Attack  Defense  \
# 68    63                       Abra  Psychic     NaN   25      20       15
# 153  142                 Aerodactyl     Rock  Flying   80     105       65
# 154  142  AerodactylMega Aerodactyl     Rock  Flying   80     135       85
# 70    65                   Alakazam  Psychic     NaN   55      50       45
# 71    65      AlakazamMega Alakazam  Psychic     NaN   55      50       65
# ..   ...                        ...      ...     ...  ...     ...      ...
# 734  666                   Vivillon      Bug  Flying   80      52       50
# 799  721                  Volcanion     Fire   Water   80     110      120
# 792  716                    Xerneas    Fairy     NaN  126     131       95
# 793  717                    Yveltal     Dark  Flying  126     131       95
# 794  718           Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# Il parametro `ascending` puo' anch'esso essere una lista in modo da riordinare al contrario solo alcune colonne (1 = true, 0 = false)

# %%
df.sort_values(['Generation', 'Name'], ascending=[0,1])
# Out:
#        #                   Name    Type 1  Type 2   HP  Attack  Defense  \
# 750  681   AegislashBlade Forme     Steel   Ghost   60     150       50
# 751  681  AegislashShield Forme     Steel   Ghost   60      50      150
# 768  698                 Amaura      Rock     Ice   77      59       50
# 753  683             Aromatisse     Fairy     NaN  101      72       72
# 769  699                Aurorus      Rock     Ice  123      77       72
# ..   ...                    ...       ...     ...  ...     ...      ...
# 76    70             Weepinbell     Grass  Poison   65      90       50
# 118  110                Weezing    Poison     NaN   65      90      120
# 45    40             Wigglytuff    Normal   Fairy  140      70       45
# 157  145                 Zapdos  Electric  Flying   90      90       85
# 46    41                  Zubat    Poison  Flying   40      45       35
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# Utizzando `df['column_name'] = ...` e' possibile creare una nuova colonna all'interno del dataframe

# %%
df['Type'] = df['Type 1'] + " - " + df['Type 2']
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary             Type
# ...

# %% [markdown]
# E' anche possibile rimuovere le delle colonne utilizzando la funzione `df.drop(columns=['column_name'])`

# %%
df = df.drop(columns=['Type'])
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# Oltre ad eleiminare delle colonne è anche possibile eliminare delle singole righe

# %%
df = df.drop([2,6,7])
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# 5      5             Charmeleon     Fire     NaN  58      64       58
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# Nello stesso modo in cui e' possibile leggere file, e' possibile anche salvarli in formato csv o excel

# %%
df.to_csv('./data/edited_pokemon.csv')
df.to_excel('./data/edited_pokemon.xlsx')
df.to_json('./data/edited_pokemon.json')
